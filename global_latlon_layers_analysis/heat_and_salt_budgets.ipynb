# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

from MITgcmutils import mds

# %%
from mitgcmdata import MITgcmmodel
reload(MITgcmmodel)
# Out:
# <module 'mitgcmdata.MITgcmmodel' from '/Users/rpa/RND/Public/mitgcmdata/mitgcmdata/MITgcmmodel.py'>

# %%
ddir = '/Users/rpa/RND/GCM/global_oce_latlon_layers/run/'
layers_name = '1RHO'
deltaTclock = 86400
#N = 10
#diters = 3600
iter0 = 36000
N = 30
diters = 1
#diters = 3600
trname = 'TH'

iters = range(iter0+diters, iter0+(N+1)*diters, diters)
m = MITgcmmodel.ModelInstance(output_dir=ddir, default_iter= iters[-1])

diag_GAD_fname = 'DiagGAD-T'
diag_surf_fname = 'DiagSurf-TS'

GAD_T, i, GAD_T_meta = m.rdmds(diag_GAD_fname, iters, returnmeta=True)
#GAD_T, i, GAD_T_meta = m.rdmds(diag_GAD_fname, [iters[-1],], returnmeta=True)
print GAD_T.shape
print i
print (GAD_T * m.hFacC).shape
# Out:
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/XC.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/XG.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/YC.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/YG.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DYC.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DYG.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DXC.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DXG.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/RAC.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/RC.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/RF.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DRC.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DRF.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/Depth.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/hFacC.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/hFacS.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/hFacW.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036001.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036002.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036003.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036004.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036005.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036006.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036007.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036008.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036009.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036010.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036011.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036012.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036013.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036014.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036015.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036016.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036017.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036018.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036019.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036020.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036021.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036022.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036023.meta
#  90  40  15
# (30, 11, 15, 40, 90)
# [36001, 36002, 36003, 36004, 36005, 36006, 36007, 36008, 36009, 36010, 36011, 36012, 36013, 36014, 36015, 36016, 36017, 36018, 36019, 36020, 36021, 36022, 36023, 36024, 36025, 36026, 36027, 36028, 36029, 36030]
# (30, 11, 15, 40, 90)
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036024.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036025.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036026.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036027.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036028.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036029.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036030.meta

# %%
from mitgcmdata import budgets
reload(budgets)

nplot = 10
for trname, diag_GAD_fname, diag_surf_fname, ttend_name in (
        ('TH', 'DiagGAD-T', 'DiagSurf-TS', 'TOTTTEND'),
        ('SLT', 'DiagGAD-S', 'DiagSurf-TS', 'TOTSTEND'),
    ):
    
    b = budgets.TracerBudget(m,
                    diag_GAD_fname, diag_surf_fname, trname=trname,
                    tottend_name=ttend_name, use_wmass=True,
                    iters=iters, avg_iters=True)
    
    tot_vflux, adv_vflux, diff_vflux = b.net_vertical_flux()
    tot_mflux, adv_mflux, diff_mflux = b.net_meridional_flux()
    tot_flux_div, adv_flux_div, diff_flux_div, surf_flux_div = b.flux_divergence()

    plt.figure()
    plt.plot(tot_vflux.squeeze(), m.zf, '.-',
             adv_vflux.squeeze(), m.zf, '.-',
             diff_vflux.squeeze(), m.zf, '.-')
    plt.grid()
    
#     plt.figure()

#     plt.plot(m.yg[0,:,0], tot_mflux[0].squeeze(), '.-',
#              m.yg[0,:,0], adv_mflux[0].squeeze(), '.-',
#               m.yg[0,:,0], diff_mflux[0].squeeze(), '.-')
#     plt.grid()
    
    plt.figure()
    plt.pcolormesh(b.tottend[0]); plt.colorbar()
    plt.figure()
    plt.pcolormesh(b.tottend[0] + tot_flux_div[0]); plt.colorbar()
    
    #k = np.zeros(m.Nr)
    #k[0] = 1
    k = np.arange(m.Nr)
    klev = np.tile(k[:,np.newaxis,np.newaxis], (1, m.Ny, m.Nx))
    
    #pltscale = np.median(100*np.sqrt(b.tottend**2))
    err = np.ma.masked_invalid(
                (b.tottend + tot_flux_div)**2 /
                 b.tottend**2 )
    log_err = np.ma.masked_invalid(np.log10(err))

    plt.figure()
    plt.hist(log_err.compressed().ravel(), bins=100)
    plt.hist(log_err[0].compressed().ravel(), bins=100, color='r')

    #plt.scatter(klev, log_err)
    #plt.scatter(b.tottend, tot_flux_div, c=klev, alpha=0.3)
    #plt.hist(np.log10(log_err))
    #plt.xlim([-pltscale, pltscale])
    #plt.ylim([-pltscale, pltscale])
# Out:
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036001.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036002.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036003.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036004.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036005.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036006.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036007.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036008.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036009.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036010.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036011.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036012.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036013.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036014.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036015.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036016.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036017.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036018.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036019.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036020.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036021.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036022.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036023.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036024.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036025.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036026.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036027.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036028.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036029.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-T.0000036030.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036001.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036002.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036003.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036004.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036005.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036006.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036007.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036008.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036009.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036010.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036011.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036012.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036013.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036014.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036015.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036016.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036017.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036018.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036019.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036020.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036021.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036022.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036023.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036024.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036025.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036026.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036027.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036028.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036029.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036030.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036001.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036002.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036003.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036004.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036005.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036006.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036007.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036008.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036009.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036010.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036011.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036012.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036013.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036014.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036015.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036016.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036017.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036018.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036019.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036020.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036021.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036022.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036023.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036024.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036025.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036026.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036027.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036028.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036029.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036030.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036001.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036002.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036003.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036004.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036005.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036006.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036007.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036008.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036009.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036010.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036011.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036012.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036013.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036014.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036015.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036016.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036017.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036018.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036019.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036020.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036021.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036022.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036023.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036024.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036025.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036026.meta
# surfflux_recidx 0
# surfflux.shape (30, 4, 40, 90)
# surfflux_recidx
#  2
# surfflux.shape (30, 4, 40, 90)
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036027.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036028.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036029.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagSurf-TS.0000036030.meta

# %%
plt.pcolormesh(err[0])
plt.clim([0,1])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x122f9acb0>

# %%
WSLTMASS = GAD_S[0,-1]
print WSLTMASS.shape
recip_drf = np.ma.masked_invalid((m.drf[0] * m.hFacC[0])**-1).filled(0.)
extra_surffluxS =  WSLTMASS[0] * recip_drf 

plt.pcolormesh( extra_surffluxS )
plt.colorbar()

plt.figure()
plt.pcolormesh(b.tottend[0,0] + tot_flux_div[0,0] + extra_surffluxS)
plt.colorbar()

print b.wmass_name
plt.figure()
plt.pcolormesh( b.wmass_surfflux[0] )
plt.colorbar()
# Out:
# (15, 40, 90)
# VSLTMASS
# <matplotlib.colorbar.Colorbar instance at 0x1222a4098>

# %%
GAD_S, i, GAD_S_meta = m.rdmds('DiagGAD-S', iters, returnmeta=True)
print GAD_S_meta['fldlist']
plt.pcolormesh(GAD_S[0,-1,0] * m.rac[0])
# Out:
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036001.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036002.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036003.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036004.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036005.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036006.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036007.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036008.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036009.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036010.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036011.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036012.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036013.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036014.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036015.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036016.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036017.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036018.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036019.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036020.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036021.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036022.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036023.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036024.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036025.meta
# ['TOTSTEND', 'ADVr_SLT', 'ADVx_SLT', 'ADVy_SLT', 'DFrE_SLT', 'DFxE_SLT', 'DFyE_SLT', 'DFrI_SLT', 'USLTMASS', 'VSLTMASS', 'WSLTMASS']
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036026.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036027.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036028.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036029.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagGAD-S.0000036030.meta

# %%
recip_drf = np.ma.masked_invalid((m.drf[0] * m.hFacC[0])**-1).filled(0.)
my_surffluxT =  -surf_ts.mean(axis=0)[0] * recip_drf / m.runit2mass / m.heat_capacity_cp
my_surffluxS =  -surf_ts.mean(axis=0)[2] * recip_drf / m.runit2mass

# %%
plt.pcolormesh(my_surffluxT)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11ce01128>

# %%
# T = m.rdmds('Ttave', iters)
# S = m.rdmds('Stave', iters)
# U = m.rdmds('Uveltave', iters)
# V = m.rdmds('Vveltave', iters)
# W = m.rdmds('Wveltave', iters)
U, V, W, T, S = m.rdmds('DiagUVWTS', iters[0])

div_UVW = m.flux_divergence(U, V, W)
TdivUVW = T * div_UVW
SdivUVW = S * div_UVW
# Out:
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/DiagUVWTS.0000036001.meta

# %%
plt.pcolormesh(SdivUVW[0])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1202de7a0>

# %%
plt.pcolormesh((b.tottend + tot_flux_div)[3])
plt.clim([-5e-9, 5e-9])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x12d4db248>

# %%
rms_div = m.mask_field(np.sqrt((SdivUVW)**2))

plt.figure()
plt.hist(np.log10(rms_div).compressed().ravel(), bins=100)
# Out:
# -c:4: RuntimeWarning: divide by zero encountered in log10
# (array([   1.,    0.,    0.,    0.,    0.,    3.,    0.,    2.,    0.,
#            0.,    0.,    2.,    2.,    3.,    3.,    0.,    3.,    1.,
#            1.,    1.,    3.,    6.,    6.,    7.,    7.,    9.,   16.,
#           15.,   17.,   14.,   24.,   16.,   23.,   22.,   32.,   37.,
#           51.,   41.,   59.,   57.,   67.,   79.,   97.,  119.,  153.,
#          168.,  171.,  194.,  214.,  242.,  313.,  322.,  405.,  423.,
#          477.,  548.,  584.,  607.,  707.,  719.,  720.,  810.,  797.,
#          835.,  844.,  881.,  868.,  840.,  778.,  851.,  844.,  854.,
#          806.,  868.,  811.,  774.,  769.,  752.,  719.,  718.,  630.,
#          665.,  636.,  590.,  578.,  506.,  441.,  396.,  372.,  336.,
#          233.,  190.,  163.,  119.,   79.,   69.,   39.,   20.,    8.,    6.]),
#  array([-18.32378039, -18.26029378, -18.19680716, -18.13332055,
#         -18.06983393, -18.00634732, -17.94286071, -17.87937409,
#         -17.81588748, -17.75240087, -17.68891425, -17.62542764,
#         -17.56194103, -17.49845441, -17.4349678 , -17.37148118,
#         -17.30799457, -17.24450796, -17.18102134, -17.11753473,
#         -17.05404812, -16.9905615 , -16.92707489, -16.86358827,
#         -16.80010166, -16.73661505, -16.67312843, -16.60964182,
#         -16.54615521, -16.48266859, -16.41918198, -16.35569537,
#         -16.29220875, -16.22872214, -16.16523552, -16.10174891,
#         -16.0382623 , -15.97477568, -15.91128907, -15.84780246,
#         -15.78431584, -15.72082923, -15.65734262, -15.593856  ,
#         -15.53036939, -15.46688277, -15.40339616, -15.33990955,
#         -15.27642293, -15.21293632, -15.14944971, -15.08596309,
#         -15.02247648, -14.95898986, -14.89550325, -14.83201664,
#         -14.76853002, -14.70504341, -14.6415568 , -14.57807018,
#         -14.51458357, -14.45109696, -14.38761034, -14.32412373,
#         -14.26063711, -14.1971505 , -14.13366389, -14.07017727,
#         -14.00669066, -13.94320405, -13.87971743, -13.81623082,
#         -13.75274421, -13.68925759, -13.62577098, -13.56228436,
#         -13.49879775, -13.43531114, -13.37182452, -13.30833791,
#         -13.2448513 , -13.18136468, -13.11787807, -13.05439145,
#         -12.99090484, -12.92741823, -12.86393161, -12.800445  ,
#         -12.73695839, -12.67347177, -12.60998516, -12.54649855,
#         -12.48301193, -12.41952532, -12.3560387 , -12.29255209,
#         -12.22906548, -12.16557886, -12.10209225, -12.03860564, -11.97511902]),
#  <a list of 100 Patch objects>)

# %%
plt.pcolormesh(surf_flux_div)

# %%
div_TUVW = m.flux_divergence(U, V, W, T)

# %%
plt.pcolormesh(div_TUVW.mean(axis=0)[0])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10e5fed88>

# %%
plt.pcolormesh(adv_flux_div[0])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11c0cc638>

# %%
plt.pcolormesh(T[-1,0] - T[0,0])
plt.clim([-0.2,0.2])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x113cb0518>

# %%
plt.pcolormesh(b.tottend[0] * (24*60*60*360*100))
plt.clim([-0.2,0.2])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x113c537e8>

# %%
eta2 = m.rdmds('Eta2tave')
eta = m.rdmds('Etatave')
# Out:
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/Eta2tave.0000072000.meta
# /Users/rpa/RND/GCM/global_oce_latlon_layers/run/Etatave.0000072000.meta

# %%
plt.pcolormesh(eta2 - eta**2)

# %%
np.testing.assert_array_almost_equal(surf_ts[2], surf_ts[3])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-272-2faabce7aa2a> in <module>()
# ----> 1 np.testing.assert_array_almost_equal(surf_ts[2], surf_ts[3])
#
# /Users/rpa/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/testing/utils.pyc in assert_array_almost_equal(x, y, decimal, err_msg, verbose)
#     809         return around(z, decimal) <= 10.0**(-decimal)
#     810     assert_array_compare(compare, x, y, err_msg=err_msg, verbose=verbose,
# --> 811              header=('Arrays are not almost equal to %d decimals' % decimal))
#     812
#     813 def assert_array_less(x, y, err_msg='', verbose=True):
#
# /Users/rpa/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/testing/utils.pyc in assert_array_compare(comparison, x, y, err_msg, verbose, header)
#     642                                 names=('x', 'y'))
#     643             if not cond :
# --> 644                 raise AssertionError(msg)
#     645     except ValueError as e:
#     646         import traceback
#
# AssertionError:
# Arrays are not almost equal to 6 decimals
#
# (mismatch 46.8611111111%)
#  x: array([[[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,...
#  y: array([[[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,...

# %%
plt.scatter(surf_ts[2], surf_ts[3])

# %%
surf_meta
# Out:
# {'dataprec': ['float32'],
#  'dimlist': [90, 40],
#  'fldlist': ['TFLUX', 'surForcT', 'SFLUX', 'surForcS'],
#  'missingvalue': [-999.0],
#  'ndims': [2],
#  'nflds': [4],
#  'nrecords': [4],
#  'simulation': ['global_oce_latlon'],
#  'timeinterval': [[3421440000.0, 3732480000.0],
#   [3732480000.0, 4043520000.0],
#   [4043520000.0, 4354560000.0],
#   [4354560000.0, 4665600000.0],
#   [4665600000.0, 4976640000.0],
#   [4976640000.0, 5287680000.0],
#   [5287680000.0, 5598720000.0],
#   [5598720000.0, 5909760000.0],
#   [5909760000.0, 6220800000.0]],
#  'timestepnumber': [43200,
#   46800,
#   50400,
#   54000,
#   57600,
#   61200,
#   64800,
#   68400,
#   72000]}
