# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
from mitgcmdata import MITgcmmodel
from mitgcmdata import layers
reload(layers)

# %matplotlib inline
plt.rcParams['image.origin'] = 'bottom'
plt.rcParams['figure.figsize'] = (10,6)

# %% [markdown]
# ### data.diagnostics ###
#
#     filename(1) = 'DiagLAYERS-transport',
#     frequency(1) = 31536000.,
#     fields(1:6,1)= 'LaUH1RHO','LaHw1RHO','LaPw1RHO',
#                  'LaVH1RHO','LaHs1RHO','LaPs1RHO',
#     filename(2) = 'DiagLAYERS-diapycnal',
#     frequency(2) = 31536000.,
#     fields(1:10,2)= 'LaTs1RHO','LaTh1RHO','LaTr1RHO',
#                  'LTha1RHO','LTra1RHO',
#                  'LaSs1RHO','LaSh1RHO','LaSr1RHO',
#                  'LSha1RHO','LSra1RHO',
#     #                 'LaHc1RHO','LaPc1RHO',
#     filename(3) = 'DiagLAYERS-trend',
#     frequency(3) = -31536000.,
#     timePhase(3) = 0.,
#     fields(1,3) = 'LaHc1RHO',

# %%
def process_layers(ddir, iter0, diters, N, deltaTclock=900, layers_name='1RHO'):

    iters = range(iter0,iter0+N*diters,diters)
    DT = diters * deltaTclock
    m = MITgcmmodel.ModelInstance(ddir, default_iter=list(iters))


    layers_transport = m.rdmds('DiagLAYERS-transport', iters[1:]).mean(axis=0)
    uh, vh = layers_transport[0], layers_transport[3]
    hw, hs = layers_transport[1,::-1], layers_transport[4,::-1]
    pi_s = layers_transport[5,::-1]
    
    layers_diapycnal = m.rdmds('DiagLAYERS-diapycnal', iters[1:]).mean(axis=0)
    layers_trend = m.rdmds('DiagLAYERS-trend', iters)

    # process data
    la = layers.LayersAnalyzer(m, layers_name=layers_name)
    dvol_dt = la.volume_trend(layers_trend[np.r_[0,-1]], DT*(N-1))
    #dvol_dt = la.volume_trend(layers_trend, DT)
    #if dvol_dt.ndim == 4:
    #    # average over time
    #    dvol_dt = dvol_dt.mean(axis=0)

    # everything but the advective tendencies
    diapycnal_vel = la.diapycnal_velocity(layers_diapycnal[np.r_[:3,5:8]])

    advective_vel = la.advective_flux_divergence(uh, vh)
    
    # "direct" form of advective vel
    advective_vel_direct = la.diapycnal_velocity(layers_diapycnal[np.r_[3,4,8,9]]).sum(axis=0)
    
    # "TOTTEND"
    diapycnal_vel_tottend = -la.diapycnal_velocity(layers_diapycnal[np.r_[10,11]]/(24*60*60)).sum(axis=0)
    
    diapycnal_vel_numerical = dvol_dt - diapycnal_vel.sum(axis=0) - advective_vel
    diapycnal_vel_numerical_direct = dvol_dt - diapycnal_vel.sum(axis=0) - advective_vel_direct

    
    psi = la.calculate_moc(vh) / 1e6
    print psi.shape

    # something is wrong with this
    pi = pi_s.mean(axis=-1)
    
    return {'dvol_dt': dvol_dt,
            'diapycnal_vel': diapycnal_vel,
            'advective_vel': advective_vel,
            'advective_vel_direct': advective_vel_direct,
            'diapycnal_vel_numerical': diapycnal_vel_numerical,
            'diapycnal_vel_tottend': diapycnal_vel_tottend,
            'diapycnal_vel_numerical_direct': diapycnal_vel_numerical_direct,
            'uh': uh, 'vh': vh, 'hs': hs, 'hw': hw,
            'psi': psi, 'pi': pi, 'la': la, 'm': m}

def plot_diapycnal_velocities(d, r=0.7e6, layers_lim=[28.2, 22], depth_lim=[-5000,0],
                              direct=False, zcoord=True):
    
    if direct:
        diapyc_suff = '_direct'
    else:
        diapyc_suff = ''

    m = d['m']
    Yg = np.hstack([m.yg[0,:,0], 2*m.yg[0,-1,0]-m.yg[0,-2,0]])
    Xg = np.hstack([m.xg[0,0,:], 2*m.xg[0,0,-1]-m.xg[0,0,-2]])
    Yc = m.yc[0,:,0]
    Xc = m.xc[0,0,:]

    lb = d['la'].layers_bounds_w - 1000.
    lbc = d['la'].layers_top - 1000.

    if zcoord:
        zw = np.cumsum(d['hs'].mean(axis=-1)[::-1], axis=0)
        # index goes down from the surface
        # pcolor needs boundaries
        zc = -np.vstack([zw[0][np.newaxis,:]/2,
                        0.5*(zw[1:] + zw[:-1])])[::-1]
        zc = np.hstack([zc, zc[:,-1][:,np.newaxis]])
        Ygz = np.tile(Yg[np.newaxis,:], (zc.shape[0],1))

        zw = -np.vstack([np.zeros((1,m.Ny)), zw[:-1]])[::-1]
        Ycz = np.tile(Yc[np.newaxis,:], (zw.shape[0],1))
        ylim=[-5000,0]

        Xpc = Ygz
        Ypc = zc
        Xc = Ycz
        Yc = zw
        ylim = depth_lim
    else:
        Xpc = Yg
        Ypc = lb
        Xc = Yc
        Yc = lbc
        ylim = layers_lim
        
    
    plt.figure(figsize=(16,12))

    plt.subplot(221)
    plt.pcolormesh(Xpc, Ypc, d['diapycnal_vel'].sum(axis=0).sum(axis=-1), cmap='RdBu_r')
    plt.clim([-r, r])
    plt.colorbar()
    plt.contour(Xc, Yc, d['psi'], 10, colors='k')
    #plt.contour(Yg[:-1], lbc, pi, [0.05, 0.5, 0.95], colors='y')
    plt.ylim(ylim)
    plt.title('Explicit Diapycnal Velocity')

    plt.subplot(222)
    plt.pcolormesh(Xpc, Ypc, d['dvol_dt'].sum(axis=-1), cmap='RdBu_r')
    plt.clim([-r, r])
    plt.colorbar()
    plt.contour(Xc, Yc, d['psi'], 10, colors='k')
    plt.ylim(ylim)
    plt.title('Volume Trend')

    plt.subplot(223)
    plt.pcolormesh(Xpc, Ypc, d['advective_vel' + diapyc_suff].sum(axis=-1), cmap='RdBu_r')
    plt.clim([-r, r])
    plt.colorbar()
    plt.contour(Xc, Yc, d['psi'], 10, colors='k')
    plt.ylim(ylim)
    plt.title('Advective Diapycnal Velocity')

    plt.subplot(224)
    plt.pcolormesh(Xpc, Ypc, d['diapycnal_vel_numerical' + diapyc_suff].sum(axis=-1), cmap='RdBu_r')
    plt.clim([-r, r])
    plt.colorbar()
    plt.contour(Xc, Yc, d['psi'], 10, colors='k')
    plt.ylim(ylim)
    plt.title('Numerical Diapycnal Velocity')
    
def layers_plot(Xpc, Ypc, field, r, Xc, Yc, psi, ylim, title, sigma=None, ax=None):
    if ax is None:
        ax = plt.subplot(111)
    pc = ax.pcolormesh(Xpc, Ypc, field, cmap='RdBu_r')
    pc.set_clim([-r, r])
    plt.colorbar(pc)
    ax.contour(Xc, Yc, psi, 16, colors='0.5')
    ax.set_ylim(ylim)
    ax.set_title(title)
    if sigma is not None:
        c = ax.contour(Xc, Yc, sigma, [27.9,27.5,27.2,27.0,26.5,26.0], colors='k')
        #manual_locations =[(-200, -70), (-200, -60), (-200, -55), 
        #                   (-200, -50), (-200, -40), (-200, -30)]

        plt.clabel(c, fmt='%1.1f', use_clabeltext=True )
        #manual=True, manual_locations=manual_locations)

# %%
# the controlled run
#ddir = '/glade/scratch/rpa/SOSE/run_matt_layers'
#N = 6

ddir = '/glade/scratch/rpa/SOSE/run_matt_layers_fgf01'
N = 7


iter0 = 0
#diters= 480
diters=35040
deltaTclock = 900
layers_name = '1RHO'

d = process_layers(ddir, iter0, diters, N, deltaTclock, layers_name)
# Out:
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/XC.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/XG.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/YC.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/YG.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DYC.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DYG.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DXC.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DXG.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/RAC.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/RC.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/RF.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DRC.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DRF.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/Depth.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/hFacC.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/hFacS.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/hFacW.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-transport.0000035040.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-transport.0000070080.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-transport.0000105120.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-transport.0000140160.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-transport.0000175200.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-transport.0000210240.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-diapycnal.0000035040.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-diapycnal.0000070080.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-diapycnal.0000105120.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-diapycnal.0000140160.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-diapycnal.0000175200.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-diapycnal.0000210240.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-trend.0000000000.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-trend.0000035040.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-trend.0000070080.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-trend.0000105120.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-trend.0000140160.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-trend.0000175200.meta
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/DiagLAYERS-trend.0000210240.meta
# 2160 320  42
# cint.shape =
#  (69, 320, 2160)
# (69, 320)
# /glade/scratch/rpa/SOSE/run_matt_layers_fgf01/layers1RHO.meta

# %%
plot_diapycnal_velocities(d, depth_lim=[-2000,0], r=4e5, zcoord=True)

# %%
plot_diapycnal_velocities(d, depth_lim=[-1000,0], r=3e5, direct=True, zcoord=True)

# %%
m = d['m']
Yg = np.hstack([m.yg[0,:,0], 2*m.yg[0,-1,0]-m.yg[0,-2,0]])
Xg = np.hstack([m.xg[0,0,:], 2*m.xg[0,0,-1]-m.xg[0,0,-2]])
Yc = m.yc[0,:,0]
Xc = m.xc[0,0,:]

lb = d['la'].layers_bounds_w - 1000.
lbc = d['la'].layers_top - 1000.


zw = np.cumsum(d['hs'].mean(axis=-1)[::-1], axis=0)
# index goes down from the surface
# pcolor needs boundaries
zc = -np.vstack([zw[0][np.newaxis,:]/2,
                0.5*(zw[1:] + zw[:-1])])[::-1]
zc = np.hstack([zc, zc[:,-1][:,np.newaxis]])
Ygz = np.tile(Yg[np.newaxis,:], (zc.shape[0],1))

zw = -np.vstack([np.zeros((1,m.Ny)), zw[:-1]])[::-1]
Ycz = np.tile(Yc[np.newaxis,:], (zw.shape[0],1))
ylim=[-5000,0]

Xpc = Ygz
Ypc = zc
Xc = Ycz
Yc = zw

sigma = np.tile(lbc[:,np.newaxis],[1, m.Ny])
print sigma.shape
print Xc.shape
# Out:
# (69, 320)
# (69, 320)

# %%
layers_plot(Xpc, Ypc, d['diapycnal_vel'].sum(axis=0).sum(axis=-1), 2e5,
            Xc, Yc, d['psi'], [-1000,0], 'tottend', sigma=sigma)

# %%
plt.figure(figsize=(16,16))
for n,idx,tit in zip(range(1,7),
                 [0,3,1,4,2,5],
                 ['Surface Heat', 'Surface FW',
                  'T Horiz. Mixing', 'S Horiz. Mixing',
                  'T Vert. Mixing', 'S Vert. Mixing']):
    ax = plt.subplot(3,2,n)
    layers_plot(Xpc, Ypc, d['diapycnal_vel'][idx].sum(axis=-1), 1e5,
            Xc, Yc, d['psi'], [-1000,0], tit, sigma=sigma, ax=ax)

# %%
layers_plot(Xpc, Ypc, -1.8*d['diapycnal_vel_tottend'].sum(axis=-1), 2e5,
            Xc, Yc, d['psi'], [-1000,0], 'tottend', sigma=sigma)

# %%
layers_plot(Xpc, Ypc, d['dvol_dt'].sum(axis=-1), 2e5, Xc, Yc, d['psi'], [-1000,0], 'dvol_dt')

# %%
r=4e5
snllim = r/10
ylim = [28, 26]

m = d['m']
Yg = np.hstack([m.yg[0,:,0], 2*m.yg[0,-1,0]-m.yg[0,-2,0]])
Xg = np.hstack([m.xg[0,0,:], 2*m.xg[0,0,-1]-m.xg[0,0,-2]])
Yc = m.yc[0,:,0]
Xc = m.xc[0,0,:]

lb = d['la'].layers_bounds_w - 1000.
lbc = d['la'].layers_top - 1000.



plt.figure(figsize=(16,12))

plt.subplot(321)
plt.pcolormesh(Yg, lb, d['diapycnal_vel'].sum(axis=0).sum(axis=-1), cmap='RdBu_r', 
               norm=matplotlib.colors.SymLogNorm(snllim))
plt.clim([-r, r])
plt.colorbar()
plt.contour(Yg[:-1], lbc, d['psi'], 10, colors='k')
#plt.contour(Yg[:-1], lbc, pi, [0.05, 0.5, 0.95], colors='y')
plt.ylim(ylim)
plt.title('Diapycnal')

plt.subplot(322)
plt.pcolormesh(Yg, lb, d['advective_vel_direct'].sum(axis=-1), cmap='RdBu_r',
               norm=matplotlib.colors.SymLogNorm(snllim))
plt.clim([-r, r])
plt.colorbar()
plt.contour(Yg[:-1], lbc, d['psi'], 10, colors='k')
#plt.contour(Yg[:-1], lbc, pi, [0.05, 0.5, 0.95], colors='y')
plt.ylim(ylim)
plt.title('Advection')

plt.subplot(323)
plt.pcolormesh(Yg, lb, (d['diapycnal_vel'].sum(axis=0)
                        + d['advective_vel_direct']).sum(axis=-1), cmap='RdBu_r',
               norm=matplotlib.colors.SymLogNorm(snllim))
plt.clim([-r,r])
plt.colorbar()
plt.contour(Yg[:-1], lbc, d['psi'], 10, colors='k')
#plt.contour(Yg[:-1], lbc, pi, [0.05, 0.5, 0.95], colors='y')
plt.ylim(ylim)
plt.title('Reconstucted Tottend')

plt.subplot(324)
plt.pcolormesh(Yg, lb, -d['diapycnal_vel_tottend'].sum(axis=-1), cmap='RdBu_r',
               norm=matplotlib.colors.SymLogNorm(snllim))
plt.clim([-r,r])
plt.colorbar()
plt.contour(Yg[:-1], lbc, d['psi'], 10, colors='k')
#plt.contour(Yg[:-1], lbc, pi, [0.05, 0.5, 0.95], colors='y')
plt.ylim(ylim)
plt.title('Tottend')

plt.subplot(325)
plt.pcolormesh(Yg, lb, d['dvol_dt'].sum(axis=-1)/2, cmap='RdBu_r',
               norm=matplotlib.colors.SymLogNorm(snllim))
plt.clim([-r,r])
plt.colorbar()
plt.contour(Yg[:-1], lbc, d['psi'], 10, colors='k')
#plt.contour(Yg[:-1], lbc, pi, [0.05, 0.5, 0.95], colors='y')
plt.ylim(ylim)
plt.title('dvol_dt')

# %%
err = np.ma.masked_invalid(
        np.sqrt((d['diapycnal_vel'].sum(axis=0) + d['advective_vel_direct'] 
                 +d['diapycnal_vel_tottend'])**2 /
         d['diapycnal_vel_tottend']**2 ))[...,:300,:]
log_err = np.ma.masked_invalid(np.log10(err))

# %%
plt.figure()
plt.hist(log_err.compressed().ravel(), bins=100);
plt.xlabel(r'log$_{10}$(rms error)')
plt.title(r'Error Histogram for %s ((TOTTEND - CACLULATED)$^2$ / TOTTEND$^2$)$^{1/2}$')

# %%
r=3e3
snllim = r/20

#for n in range(22,35):
n = 10
plt.figure(figsize=(16,6))
plt.contour(Xc, Yc, m.depth, [0,50,500,1000,2000,4000], colors='k', alpha=0.2)
plt.pcolormesh(Xc,Yc, d['diapycnal_vel'][:,n].sum(axis=0), cmap='RdBu_r',
               norm=matplotlib.colors.SymLogNorm(snllim))
plt.clim([-r, r])
plt.title(lb[n])

# %%
def rebin(a, shape):
    sh = shape[0],a.shape[0]//shape[0],shape[1],a.shape[1]//shape[1]
    #print sh
    return a.reshape(sh).sum(-1).sum(1)

# %%
# Out:
# (320, 2160)

# %%
# Out:
# (40, 8, 270, 8)
# (40, 270)

# %%
r=1e4

#uh = rebin(d['uh'][-n], (320/8, 2160/8))
#vh = rebin(d['vh'][-n], (320/8, 2160/8))


plt.pcolormesh(w, cmap='RdBu_r')
plt.clim([-r,r])
#plt.quiver(uh, vh, scale=2e4)
plt.title(lb[n])

# %%
nlevs = np.arange(10,24)
clevs = (nlevs - nlevs[0])/float(len(nlevs))
for n, cidx in zip(nlevs, clevs):

    #for n in range(14):

    w = rebin(d['diapycnal_vel'][:,n].sum(axis=0), (320/8, 2160/8))
    #w_pos_cum = np.ma.masked_less(w[:15],0).sum(axis=-2)#.cumsum(axis=-1)
    #w_neg_cum = np.ma.masked_greater(w[:15],0).sum(axis=-2)#.cumsum(axis=-1)
    #plt.plot(w_neg_cum, color='b')
    #plt.plot(w_pos_cum, color='r')
    
    wsum = w[10:18].sum(axis=-2)
    wcum = wsum.cumsum(axis=-1)
    plt.plot(Xc[::8], wcum,
             label=('%4.2f' % lb[n]), color=plt.cm.jet(cidx))

plt.legend(loc='lower left')

# %%
clevs
# Out:
# array([ 0.        ,  0.28571429,  0.57142857,  0.85714286,  1.14285714,
#         1.42857143,  1.71428571])

# %%
Yc[::8][np.r_[10,17]]
# Out:
# array([-64.54163361, -55.20829773])

# %%
plt.plot(Xc[::8], w[10:18].sum(axis=-2).cumsum(axis=-1))

# %%
la = d['la']
print la.la
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ec18689f8642> in <module>()
# ----> 1 la = d['la']
#       2 print la.la
#
# NameError: name 'd' is not defined

# %%
zw = np.cumsum(d['hs'].mean(axis=-1)[::-1], axis=0)
# index goes down from the surface
# pcolor needs boundaries
zc = np.vstack([zw[0][np.newaxis,:]/2,
                0.5*(zw[1:] + zw[:-1])])[::-1]

# %%
plt.pcolormesh(zc)

# %%
zc.shape
# Out:
# (69, 320)

# %%
d['diapycnal_vel'].shape
# Out:
# (6, 68, 320, 2160)

# %%
d['la'].layers_top
# Out:
# array([ 1028.69995117,  1028.5       ,  1028.30004883,  1028.09997559,
#         1027.90002441,  1027.89501953,  1027.88769531,  1027.87817383,
#         1027.86645508,  1027.85229492,  1027.83605957,  1027.81738281,
#         1027.79650879,  1027.7734375 ,  1027.74804688,  1027.72033691,
#         1027.69042969,  1027.6583252 ,  1027.6237793 ,  1027.5871582 ,
#         1027.5480957 ,  1027.50683594,  1027.46337891,  1027.41760254,
#         1027.36950684,  1027.31921387,  1027.26660156,  1027.21179199,
#         1027.15466309,  1027.09533691,  1027.03369141,  1026.96972656,
#         1026.90356445,  1026.83520508,  1026.7644043 ,  1026.69152832,
#         1026.61621094,  1026.53869629,  1026.45898438,  1026.37695312,
#         1026.29260254,  1026.20605469,  1026.11730957,  1026.02612305,
#         1025.93286133,  1025.8371582 ,  1025.73925781,  1025.63916016,
#         1025.53674316,  1025.43200684,  1025.32507324,  1025.21582031,
#         1025.10437012,  1024.99060059,  1024.87463379,  1024.75634766,
#         1024.63574219,  1024.51293945,  1024.38793945,  1024.26049805,
#         1024.13098145,  1023.99908447,  1023.8649292 ,  1023.72851562,
#         1023.58984375,  1023.44891357,  1023.3057251 ,  1023.16021729,
#         1023.01251221])

# %%
zw = np.cumsum(d['hs'].mean(axis=-1)[::-1], axis=0)
# index goes down from the surface
# pcolor needs boundaries
zc = -np.vstack([zw[0][np.newaxis,:]/2,
                0.5*(zw[1:] + zw[:-1])])[::-1]
zc = np.hstack([zc, zc[:,-1][:,np.newaxis]])
Ygz = np.tile(Yg[np.newaxis,:], (zc.shape[0],1))

zw = -np.vstack([np.zeros((1,m.Ny)), zw[::-1][:-1]])
Ycz = np.tile(Yc[np.newaxis,:], (zw.shape[0],1))
ylim=[-5000,0]

Xpc = Ygz
Ypc = zc
Xc = Ycz
Yc = zw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9fcc06201cdf> in <module>()
#       5                 0.5*(zw[1:] + zw[:-1])])[::-1]
#       6 zc = np.hstack([zc, zc[:,-1][:,np.newaxis]])
# ----> 7 Ygz = np.tile(Yg[np.newaxis,:], (zc.shape[0],1))
#       8
#       9 zw = -np.vstack([np.zeros((1,m.Ny)), zw[::-1][:-1]])
#
# NameError: name 'Yg' is not defined

# %%
plt.pcolormesh(Yc)
